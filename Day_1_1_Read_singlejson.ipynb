# %%
df = spark.read.json("/Volumes/azuredatabricks1/default/employee/JSON/employees_single.json",)
df.show()

# %%
df = spark.read.option("multiline", "true").json("/Volumes/azuredatabricks1/default/employee/JSON/employees_multiline.json")
df.show()

# %%
df = spark.read.json("/Volumes/azuredatabricks1/default/employee/JSON/employees_single.json")     
df = df.filter(df.salary > 40000)           
df = df.select("name")                
df.show()                             # execution happens here

# %%
df = spark.read.option("multiline", "true").json("/Volumes/azuredatabricks1/default/employee/JSON/orders_complex.json")
df.show()
