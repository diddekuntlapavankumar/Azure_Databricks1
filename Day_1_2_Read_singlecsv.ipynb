# %%
df = spark.read.csv("/Volumes/azuredatabricks1/default/employee/CSV/customers.csv",)
df.show()

# %%
# Displays the schema (column names and types) of the DataFrame
df.printSchema()

# Returns a list of column names in the DataFrame
df.columns

# Returns the number of rows in the DataFrame
df.count()

# %%
df.filter("name = 'ram'").show()

# %%
df = spark.read.csv("/Volumes/azuredatabricks1/default/employee/CSV/employees.csv",)
df.show()

# %%
df.filter("salary > 50000").show()

# %%
df = spark.read.option("header", "true").csv("/Volumes/azuredatabricks1/default/employee/CSV/employees.csv")
df = df.filter(df.salary > 45000)
df = df.select("name")
count = df.count()
print(count)
df.show()
